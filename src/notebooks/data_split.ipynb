# %%
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split
import re
from pathlib import Path
import cv2 as cv

# %%
img_path = '/work3/s220243/Thesis'
base_path = '/zhome/ac/d/174101/thesis'

# %%
df = pd.read_excel(f"{base_path}/data/imageAnalysis_information.xlsx")
df  = pd.DataFrame(df.values[1:], columns=df.iloc[0])
df.head()
# Out:
# 0 event_id IBT number        genus      species start date    end date  \
# 0   ima001  IBT 12085  Penicillium      smithii  2023-02-20 2023-02-27
# 1   ima001  IBT 13516  Penicilluim      bilaiae  2023-02-20 2023-02-27
# 2   ima001  IBT 21948  Penicilluim  malodoratum  2023-02-20 2023-02-27
# 3   ima001  IBT 21902  Aspergillus   astellatus  2023-02-20 2023-02-27
# 4   ima001     NID174  Aspergillus     nidulans  2023-02-20 2023-02-27
#
# 0 date of picture image no video temperature picture interval comments  \
# 0           day 4      192   NaN          25           30 min      NaN
# 1           day 4      192   NaN          25           30 min      NaN
# 2           day 4      192   NaN          25           30 min      NaN
# 3           day 4      192   NaN          25           30 min      NaN
# 4           day 4      192   NaN          25           30 min      NaN
#
# 0 Reshape Job ID Reshape plate position Ofba reference list Comments
# 0            NaN                    NaN                 NaN      NaN
# 1            NaN                    NaN                 NaN      NaN
# 2            NaN                    NaN                 NaN      NaN
# 3            NaN                    NaN                 NaN      NaN
# 4            NaN                    NaN                 NaN      NaN

# %%
species_genus_df = pd.DataFrame({"IBT_number": df['IBT number'],
                          "Target" : df["genus"]+"-"+df["species"]})
species_genus_df.dropna()
# Out:
#     IBT_number                     Target
# 0    IBT 12085        Penicillium-smithii
# 1    IBT 13516        Penicilluim-bilaiae
# 2    IBT 21948    Penicilluim-malodoratum
# 3    IBT 21902     Aspergillus-astellatus
# 4       NID174       Aspergillus-nidulans
# ..         ...                        ...
# 163  IBT 32197  Purpureocillium-lilacinum
# 164  IBT 32286         Aspergillus-wentii
# 165  IBT 32384    Aspergillus-aculeatinus
# 166  IBT 32420          Aspergillus-ustus
# 167  IBT 32349      Penicillium-velutinum
#
# [161 rows x 2 columns]

# %%
ibt_numbers=[]
img_paths=[]

# Get a list of all the images paths
img = Path(f"{img_path}/images")
paths = list(img.glob('**/*.jpeg'))

# Create list of all IBTs and paths to images for the given IBT
for path in paths:
  match = re.search(r'IBT \d+',str(path))
  if match:
    ibt_numbers.append(match.group())
    img_paths.append(str(path))
  else:
    ibt_numbers.append("ACU1")
    img_paths.append(str(path))

# Create DF from a lists
paths_df = pd.DataFrame({"IBT_number": ibt_numbers,
                     "path": img_paths})

# Merge target_df and paths_df
paths_df = paths_df.groupby('IBT_number')['path'].apply(list).reset_index()
merged_df = pd.merge(species_genus_df, paths_df, on='IBT_number', how='inner')
target_paths_df = merged_df.explode('path')
target_paths_df

# Drop all images that are prior to day 2
target_paths_df['Image_number'] = target_paths_df['path'].apply(lambda x: x.split('/')[-1].split('.')[0])
target_paths_df['Image_number'] = target_paths_df['Image_number'].str.replace(r'\D', '', regex=True)
target_paths_df['Image_number'] = target_paths_df['Image_number'].astype(int)
target_df = target_paths_df[(target_paths_df['Image_number'] >= 48) & (target_paths_df['Image_number'] <= 168)]
val_df = target_paths_df[(target_paths_df['Image_number'] > 168) & (target_paths_df['Image_number'] <= 192)]

# %%
def apply_lbp(image_path, output_directory):
    # Read the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    # Apply Local Binary Patterns (LBP)
    radius = 3
    n_points = 8 * radius
    lbp_image = local_binary_pattern(image, n_points, radius, method='uniform')
    
    # Convert to uint8 (required for saving)
    lbp_image_uint8 = (lbp_image * 255).astype('uint8')
    
    # Get the file name
    file_name = image_path.split('/')[-1]  # Assuming Unix-style paths
    
    # Save the processed image
    output_path = join(output_directory, file_name)
    cv2.imwrite(output_path, lbp_image_uint8)

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    image_path = row['image_path']
    output_directory = row['output_directory']
    
    # Apply LBP and save the processed image
    apply_lbp(image_path, output_directory)

# %%
base = Path(f"{img_path}/data_split")
base.mkdir(exist_ok=True)

# Create train-test split folders
train_dst = base / "train"
test_dst = base / "test"
val_dst = base / "validation"

shutil.rmtree(train_dst)
shutil.rmtree(test_dst)
shutil.rmtree(val_dst)
print('Directories removed')

train_dst.mkdir(exist_ok=True)
test_dst.mkdir(exist_ok=True)
val_dst.mkdir(exist_ok=True)

# Perform train-test split
train_df, test_df = train_test_split(target_df, test_size=0.3, random_state=42)
#test_df, val_df = train_test_split(test_df, test_size=0.3, random_state=42)

def copy_images(df, dst_folder):
  for _, row in df.iterrows():
    target_dst = dst_folder / str(row['Target'])
    target_dst.mkdir(exist_ok=True)
    #print(str(row['path']))
    shutil.copy(str(row['path']), str(target_dst))

print('copying...')

# Copy images to train directory
copy_images(train_df, train_dst)
print('train images copy finished')

# Copy images to test directory
copy_images(test_df, test_dst)
print('test images copy finished')

# Copy images to validation directory
copy_images(val_df, val_dst)
print('validation images copy finished')
# Out:
# copying...
# /work3/s220243/Thesis/images/IBT 42139/RIS1_0_TL_20_preset/98.jpeg
# /work3/s220243/Thesis/images/IBT 26504/RIS1_0_TL_20_preset/96.jpeg
# /work3/s220243/Thesis/images/IBT 42139/RIS1_0_TL_20_preset/140.jpeg
# /work3/s220243/Thesis/images/IBT 40896/RIS1_0_TL_20_preset/136.jpeg
# /work3/s220243/Thesis/images/IBT 35839/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 8189/RIS1_0_TL_20_preset/137.jpeg
# /work3/s220243/Thesis/images/IBT 21948/6w_top_medium_preset/119.jpeg
# /work3/s220243/Thesis/images/IBT 36721/RIS1_0_TL_20_preset/70.jpeg
# /work3/s220243/Thesis/images/IBT 42867/RIS1_0_TL_20_preset/61.jpeg
# /work3/s220243/Thesis/images/IBT 41274/RIS1_0_TL_20_preset/135.jpeg
# /work3/s220243/Thesis/images/IBT 31674/RIS1_0_TL_20_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 36710/RIS1_0_TL_20_preset/55.jpeg
# /work3/s220243/Thesis/images/IBT 42683/RIS1_0_TL_20_preset/69.jpeg
# /work3/s220243/Thesis/images/IBT 42198/RIS1_0_TL_20_preset/77.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 36721/RIS1_0_TL_20_preset/142.jpeg
# /work3/s220243/Thesis/images/IBT 41688/6w_top_medium_preset/113.jpeg
# /work3/s220243/Thesis/images/IBT 21948/6w_top_medium_preset/49.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/101.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/123.jpeg
# /work3/s220243/Thesis/images/IBT 36713/RIS1_0_TL_20_preset/94.jpeg
# /work3/s220243/Thesis/images/IBT 40896/RIS1_0_TL_20_preset/90.jpeg
# /work3/s220243/Thesis/images/IBT 36724/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 26575/6w_top_medium_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 31674/RIS1_0_TL_20_preset/126.jpeg
# /work3/s220243/Thesis/images/IBT 35695/RIS1_0_TL_20_preset/66.jpeg
# /work3/s220243/Thesis/images/IBT 32047/RIS1_0_TL_20_preset/106.jpeg
# /work3/s220243/Thesis/images/IBT 42464/RIS1_0_TL_20_preset/110.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/105.jpeg
# /work3/s220243/Thesis/images/IBT 23138/6w_top_medium_preset/94.jpeg
# /work3/s220243/Thesis/images/IBT 36722/RIS1_0_TL_20_preset/118.jpeg
# /work3/s220243/Thesis/images/IBT 31674/RIS1_0_TL_20_preset/77.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/110.jpeg
# /work3/s220243/Thesis/images/IBT 40303/6w_top_medium_preset/116.jpeg
# /work3/s220243/Thesis/images/ACU1/IBT 36716/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 42198/RIS1_0_TL_20_preset/64.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/57.jpeg
# /work3/s220243/Thesis/images/IBT 42221/RIS1_0_TL_20_preset/84.jpeg
# /work3/s220243/Thesis/images/IBT 21948/6w_top_medium_preset/84.jpeg
# /work3/s220243/Thesis/images/IBT 42791/RIS1_0_TL_20_preset/59.jpeg
# /work3/s220243/Thesis/images/IBT 8121/RIS1_0_TL_20_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 40953/6w_top_medium_preset/133.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/88.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/82.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/105.jpeg
# /work3/s220243/Thesis/images/IBT 36723/RIS1_0_TL_20_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 23138/6w_top_medium_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 36720/RIS1_0_TL_20_preset/102.jpeg
# /work3/s220243/Thesis/images/IBT 35445/RIS1_0_TL_20_preset/77.jpeg
# /work3/s220243/Thesis/images/IBT 35839/RIS1_0_TL_20_preset/110.jpeg
# /work3/s220243/Thesis/images/IBT 41217/RIS1_0_TL_20_preset/63.jpeg
# /work3/s220243/Thesis/images/IBT 26878/RIS1_0_TL_20_preset/106.jpeg
# /work3/s220243/Thesis/images/IBT 41919/RIS1_0_TL_20_preset/64.jpeg
# /work3/s220243/Thesis/images/IBT 42466/RIS1_0_TL_20_preset/140.jpeg
# /work3/s220243/Thesis/images/IBT 21948/6w_top_medium_preset/54.jpeg
# /work3/s220243/Thesis/images/IBT 41274/RIS1_0_TL_20_preset/58.jpeg
# /work3/s220243/Thesis/images/IBT 24472/RIS1_0_TL_20_preset/57.jpeg
# /work3/s220243/Thesis/images/IBT 40303/6w_top_medium_preset/62.jpeg
# /work3/s220243/Thesis/images/IBT 14486/6w_top_medium_preset/60.jpeg
# /work3/s220243/Thesis/images/IBT 36725/RIS1_0_TL_20_preset/77.jpeg
# /work3/s220243/Thesis/images/IBT 36711/RIS1_0_TL_20_preset/59.jpeg
# /work3/s220243/Thesis/images/IBT 42472/RIS1_0_TL_20_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 36715/RIS1_0_TL_20_preset/52.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/137.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/51.jpeg
# /work3/s220243/Thesis/images/IBT 36729/RIS1_0_TL_20_preset/85.jpeg
# /work3/s220243/Thesis/images/IBT 41495/RIS1_0_TL_20_preset/101.jpeg
# /work3/s220243/Thesis/images/IBT 35445/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 42908/RIS1_0_TL_20_preset/118.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/130.jpeg
# /work3/s220243/Thesis/images/IBT 41919/RIS1_0_TL_20_preset/48.jpeg
# /work3/s220243/Thesis/images/IBT 9051/RIS1_0_TL_20_preset/107.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/103.jpeg
# /work3/s220243/Thesis/images/IBT 40303/6w_top_medium_preset/94.jpeg
# /work3/s220243/Thesis/images/IBT 26575/6w_top_medium_preset/70.jpeg
# /work3/s220243/Thesis/images/IBT 8189/RIS1_0_TL_20_preset/53.jpeg
# /work3/s220243/Thesis/images/IBT 42735/RIS1_0_TL_20_preset/140.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/95.jpeg
# /work3/s220243/Thesis/images/IBT 8969/RIS1_0_TL_20_preset/136.jpeg
# /work3/s220243/Thesis/images/IBT 36712/RIS1_0_TL_20_preset/105.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/137.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/70.jpeg
# /work3/s220243/Thesis/images/IBT 24472/RIS1_0_TL_20_preset/76.jpeg
# /work3/s220243/Thesis/images/IBT 26878/RIS1_0_TL_20_preset/122.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/127.jpeg
# /work3/s220243/Thesis/images/IBT 35445/RIS1_0_TL_20_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 42464/RIS1_0_TL_20_preset/89.jpeg
# /work3/s220243/Thesis/images/IBT 32786/RIS1_0_TL_20_preset/49.jpeg
# /work3/s220243/Thesis/images/IBT 40303/6w_top_medium_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 32982/RIS1_0_TL_20_preset/81.jpeg
# /work3/s220243/Thesis/images/IBT 36713/RIS1_0_TL_20_preset/57.jpeg
# /work3/s220243/Thesis/images/IBT 8121/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 32047/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 42867/RIS1_0_TL_20_preset/123.jpeg
# /work3/s220243/Thesis/images/ACU1/6w_top_medium_preset/116.jpeg
# /work3/s220243/Thesis/images/IBT 41379/6w_top_medium_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 41919/RIS1_0_TL_20_preset/107.jpeg
# /work3/s220243/Thesis/images/IBT 24472/RIS1_0_TL_20_preset/68.jpeg
# /work3/s220243/Thesis/images/IBT 42760/RIS1_0_TL_20_preset/103.jpeg
# /work3/s220243/Thesis/images/IBT 36716/RIS1_0_TL_20_preset/49.jpeg
# /work3/s220243/Thesis/images/IBT 36709/RIS1_0_TL_20_preset/119.jpeg
# /work3/s220243/Thesis/images/IBT 32047/RIS1_0_TL_20_preset/95.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/114.jpeg
# /work3/s220243/Thesis/images/IBT 9051/RIS1_0_TL_20_preset/57.jpeg
# /work3/s220243/Thesis/images/IBT 41023/6w_top_medium_preset/141.jpeg
# /work3/s220243/Thesis/images/IBT 42683/RIS1_0_TL_20_preset/99.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/92.jpeg
# /work3/s220243/Thesis/images/IBT 42735/RIS1_0_TL_20_preset/82.jpeg
# /work3/s220243/Thesis/images/IBT 40382/RIS1_0_TL_20_preset/110.jpeg
# /work3/s220243/Thesis/images/IBT 42466/RIS1_0_TL_20_preset/95.jpeg
# /work3/s220243/Thesis/images/IBT 32982/RIS1_0_TL_20_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 42464/RIS1_0_TL_20_preset/120.jpeg
# /work3/s220243/Thesis/images/IBT 32982/RIS1_0_TL_20_preset/91.jpeg
# /work3/s220243/Thesis/images/IBT 36722/RIS1_0_TL_20_preset/66.jpeg
# /work3/s220243/Thesis/images/IBT 42854/RIS1_0_TL_20_preset/136.jpeg
# /work3/s220243/Thesis/images/IBT 34291/6w_top_medium_preset/106.jpeg
# /work3/s220243/Thesis/images/IBT 42867/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 42851/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 35695/RIS1_0_TL_20_preset/103.jpeg
# /work3/s220243/Thesis/images/ACU1/6w_top_medium_preset/84.jpeg
# /work3/s220243/Thesis/images/IBT 7737/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/66.jpeg
# /work3/s220243/Thesis/images/IBT 36725/RIS1_0_TL_20_preset/48.jpeg
# /work3/s220243/Thesis/images/IBT 14486/6w_top_medium_preset/102.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/125.jpeg
# /work3/s220243/Thesis/images/IBT 31674/RIS1_0_TL_20_preset/49.jpeg
# /work3/s220243/Thesis/images/IBT 36722/RIS1_0_TL_20_preset/143.jpeg
# /work3/s220243/Thesis/images/IBT 21948/6w_top_medium_preset/58.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/56.jpeg
# /work3/s220243/Thesis/images/IBT 42683/RIS1_0_TL_20_preset/49.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/108.jpeg
# /work3/s220243/Thesis/images/IBT 41912/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/134.jpeg
# /work3/s220243/Thesis/images/IBT 9212/RIS1_0_TL_20_preset/70.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/116.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/119.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/109.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/106.jpeg
# /work3/s220243/Thesis/images/IBT 36715/RIS1_0_TL_20_preset/102.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/131.jpeg
# /work3/s220243/Thesis/images/IBT 32842/RIS1_0_TL_20_preset/133.jpeg
# /work3/s220243/Thesis/images/IBT 36719/RIS1_0_TL_20_preset/113.jpeg
# /work3/s220243/Thesis/images/IBT 36722/RIS1_0_TL_20_preset/137.jpeg
# /work3/s220243/Thesis/images/IBT 25183/RIS1_0_TL_20_preset/109.jpeg
# /work3/s220243/Thesis/images/IBT 36523/RIS1_0_TL_20_preset/66.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/136.jpeg
# /work3/s220243/Thesis/images/IBT 23253/RIS1_0_TL_20_preset/85.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/135.jpeg
# /work3/s220243/Thesis/images/IBT 36722/RIS1_0_TL_20_preset/124.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/83.jpeg
# /work3/s220243/Thesis/images/IBT 42683/RIS1_0_TL_20_preset/63.jpeg
# /work3/s220243/Thesis/images/IBT 42472/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/141.jpeg
# /work3/s220243/Thesis/images/IBT 23255/RIS1_0_TL_20_preset/113.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/138.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 26575/6w_top_medium_preset/118.jpeg
# /work3/s220243/Thesis/images/IBT 36725/RIS1_0_TL_20_preset/142.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 42899/RIS1_0_TL_20_preset/115.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/143.jpeg
# /work3/s220243/Thesis/images/IBT 36714/RIS1_0_TL_20_preset/132.jpeg
# /work3/s220243/Thesis/images/IBT 12085/6w_top_medium_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 36726/RIS1_0_TL_20_preset/81.jpeg
# /work3/s220243/Thesis/images/IBT 42908/RIS1_0_TL_20_preset/63.jpeg
# /work3/s220243/Thesis/images/ACU1/IBT 36716/RIS1_0_TL_20_preset/52.jpeg
# /work3/s220243/Thesis/images/IBT 36712/RIS1_0_TL_20_preset/87.jpeg
# /work3/s220243/Thesis/images/IBT 42760/RIS1_0_TL_20_preset/72.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/109.jpeg
# /work3/s220243/Thesis/images/IBT 36729/RIS1_0_TL_20_preset/112.jpeg
# /work3/s220243/Thesis/images/IBT 42851/RIS1_0_TL_20_preset/62.jpeg
# /work3/s220243/Thesis/images/IBT 36721/RIS1_0_TL_20_preset/63.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/54.jpeg
# /work3/s220243/Thesis/images/IBT 42735/RIS1_0_TL_20_preset/141.jpeg
# /work3/s220243/Thesis/images/IBT 42908/RIS1_0_TL_20_preset/120.jpeg
# /work3/s220243/Thesis/images/IBT 26504/RIS1_0_TL_20_preset/48.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 34291/6w_top_medium_preset/53.jpeg
# /work3/s220243/Thesis/images/IBT 9051/RIS1_0_TL_20_preset/86.jpeg
# /work3/s220243/Thesis/images/IBT 36726/RIS1_0_TL_20_preset/115.jpeg
# /work3/s220243/Thesis/images/IBT 41495/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 36724/RIS1_0_TL_20_preset/68.jpeg
# /work3/s220243/Thesis/images/IBT 42683/RIS1_0_TL_20_preset/135.jpeg
# /work3/s220243/Thesis/images/IBT 40896/RIS1_0_TL_20_preset/128.jpeg
# /work3/s220243/Thesis/images/IBT 42145/RIS1_0_TL_20_preset/113.jpeg
# /work3/s220243/Thesis/images/ACU1/6w_top_medium_preset/125.jpeg
# /work3/s220243/Thesis/images/IBT 32982/RIS1_0_TL_20_preset/89.jpeg
# /work3/s220243/Thesis/images/IBT 42198/RIS1_0_TL_20_preset/84.jpeg
# /work3/s220243/Thesis/images/IBT 41688/6w_top_medium_preset/50.jpeg
# /work3/s220243/Thesis/images/IBT 41919/RIS1_0_TL_20_preset/99.jpeg
# /work3/s220243/Thesis/images/IBT 40953/6w_top_medium_preset/58.jpeg
# /work3/s220243/Thesis/images/IBT 35695/RIS1_0_TL_20_preset/51.jpeg
# /work3/s220243/Thesis/images/IBT 36727/RIS1_0_TL_20_preset/84.jpeg
# /work3/s220243/Thesis/images/IBT 36720/RIS1_0_TL_20_preset/115.jpeg
# /work3/s220243/Thesis/images/IBT 42464/RIS1_0_TL_20_preset/138.jpeg
# /work3/s220243/Thesis/images/IBT 36523/RIS1_0_TL_20_preset/93.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/68.jpeg
# /work3/s220243/Thesis/images/IBT 9212/RIS1_0_TL_20_preset/93.jpeg
# /work3/s220243/Thesis/images/IBT 23253/RIS1_0_TL_20_preset/137.jpeg
# /work3/s220243/Thesis/images/IBT 23138/6w_top_medium_preset/103.jpeg
# /work3/s220243/Thesis/images/IBT 34291/6w_top_medium_preset/57.jpeg
# /work3/s220243/Thesis/images/IBT 36715/RIS1_0_TL_20_preset/140.jpeg
# /work3/s220243/Thesis/images/IBT 42854/RIS1_0_TL_20_preset/140.jpeg
# /work3/s220243/Thesis/images/ACU1/IBT 36716/RIS1_0_TL_20_preset/127.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/131.jpeg
# /work3/s220243/Thesis/images/IBT 42221/RIS1_0_TL_20_preset/115.jpeg
# /work3/s220243/Thesis/images/IBT 23255/RIS1_0_TL_20_preset/76.jpeg
# /work3/s220243/Thesis/images/IBT 32785/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 26878/RIS1_0_TL_20_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 36720/RIS1_0_TL_20_preset/124.jpeg
# /work3/s220243/Thesis/images/IBT 36712/RIS1_0_TL_20_preset/142.jpeg
# /work3/s220243/Thesis/images/IBT 32047/RIS1_0_TL_20_preset/101.jpeg
# /work3/s220243/Thesis/images/IBT 12085/6w_top_medium_preset/108.jpeg
# /work3/s220243/Thesis/images/IBT 36724/RIS1_0_TL_20_preset/142.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/113.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/92.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/127.jpeg
# /work3/s220243/Thesis/images/IBT 26504/RIS1_0_TL_20_preset/104.jpeg
# /work3/s220243/Thesis/images/ACU1/6w_top_medium_preset/128.jpeg
# /work3/s220243/Thesis/images/IBT 42139/RIS1_0_TL_20_preset/61.jpeg
# /work3/s220243/Thesis/images/IBT 42899/RIS1_0_TL_20_preset/90.jpeg
# /work3/s220243/Thesis/images/IBT 42760/RIS1_0_TL_20_preset/132.jpeg
# /work3/s220243/Thesis/images/IBT 32842/RIS1_0_TL_20_preset/63.jpeg
# /work3/s220243/Thesis/images/IBT 36720/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 34291/6w_top_medium_preset/100.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/116.jpeg
# /work3/s220243/Thesis/images/ACU1/IBT 36716/RIS1_0_TL_20_preset/89.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/53.jpeg
# /work3/s220243/Thesis/images/IBT 41688/6w_top_medium_preset/94.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/85.jpeg
# /work3/s220243/Thesis/images/IBT 36716/RIS1_0_TL_20_preset/82.jpeg
# /work3/s220243/Thesis/images/IBT 23253/RIS1_0_TL_20_preset/127.jpeg
# /work3/s220243/Thesis/images/IBT 42473/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 41891/RIS1_0_TL_20_preset/73.jpeg
# /work3/s220243/Thesis/images/IBT 42899/RIS1_0_TL_20_preset/113.jpeg
# /work3/s220243/Thesis/images/IBT 42472/RIS1_0_TL_20_preset/114.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/89.jpeg
# /work3/s220243/Thesis/images/IBT 23253/RIS1_0_TL_20_preset/91.jpeg
# /work3/s220243/Thesis/images/IBT 24472/RIS1_0_TL_20_preset/86.jpeg
# /work3/s220243/Thesis/images/IBT 36710/RIS1_0_TL_20_preset/75.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/82.jpeg
# /work3/s220243/Thesis/images/IBT 36523/RIS1_0_TL_20_preset/123.jpeg
# /work3/s220243/Thesis/images/IBT 35695/RIS1_0_TL_20_preset/122.jpeg
# /work3/s220243/Thesis/images/ACU1/6w_top_medium_preset/65.jpeg
# /work3/s220243/Thesis/images/IBT 42464/RIS1_0_TL_20_preset/60.jpeg
# /work3/s220243/Thesis/images/IBT 36729/RIS1_0_TL_20_preset/109.jpeg
# /work3/s220243/Thesis/images/IBT 42198/RIS1_0_TL_20_preset/80.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/64.jpeg
# /work3/s220243/Thesis/images/IBT 42851/RIS1_0_TL_20_preset/139.jpeg
# /work3/s220243/Thesis/images/IBT 41961/RIS1_0_TL_20_preset/133.jpeg
# /work3/s220243/Thesis/images/IBT 36709/RIS1_0_TL_20_preset/125.jpeg
# /work3/s220243/Thesis/images/IBT 32802/RIS1_0_TL_20_preset/102.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/65.jpeg
# /work3/s220243/Thesis/images/IBT 42867/RIS1_0_TL_20_preset/102.jpeg
# /work3/s220243/Thesis/images/IBT 40382/RIS1_0_TL_20_preset/134.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/81.jpeg
# /work3/s220243/Thesis/images/IBT 42139/RIS1_0_TL_20_preset/125.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/79.jpeg
# /work3/s220243/Thesis/images/IBT 42735/RIS1_0_TL_20_preset/86.jpeg
# /work3/s220243/Thesis/images/IBT 41379/6w_top_medium_preset/65.jpeg
# /work3/s220243/Thesis/images/IBT 36729/RIS1_0_TL_20_preset/95.jpeg
# /work3/s220243/Thesis/images/IBT 36723/RIS1_0_TL_20_preset/58.jpeg
# /work3/s220243/Thesis/images/IBT 9051/RIS1_0_TL_20_preset/126.jpeg
# /work3/s220243/Thesis/images/IBT 35839/RIS1_0_TL_20_preset/115.jpeg
# /work3/s220243/Thesis/images/IBT 36720/RIS1_0_TL_20_preset/126.jpeg
# /work3/s220243/Thesis/images/IBT 42139/RIS1_0_TL_20_preset/142.jpeg
# /work3/s220243/Thesis/images/IBT 36721/RIS1_0_TL_20_preset/98.jpeg
# /work3/s220243/Thesis/images/IBT 41919/RIS1_0_TL_20_preset/75.jpeg
# /work3/s220243/Thesis/images/IBT 36727/RIS1_0_TL_20_preset/128.jpeg
# /work3/s220243/Thesis/images/IBT 42466/RIS1_0_TL_20_preset/48.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/74.jpeg
# /work3/s220243/Thesis/images/IBT 35499/RIS1_0_TL_20_preset/59.jpeg
# /work3/s220243/Thesis/images/IBT 35099/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 42841/RIS1_0_TL_20_preset/86.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 8220/RIS1_0_TL_20_preset/101.jpeg
# /work3/s220243/Thesis/images/IBT 36713/RIS1_0_TL_20_preset/144.jpeg
# /work3/s220243/Thesis/images/IBT 42908/RIS1_0_TL_20_preset/119.jpeg
# /work3/s220243/Thesis/images/IBT 40896/RIS1_0_TL_20_preset/103.jpeg
# /work3/s220243/Thesis/images/IBT 42760/RIS1_0_TL_20_preset/95.jpeg
# /work3/s220243/Thesis/images/IBT 31674/RIS1_0_TL_20_preset/121.jpeg
# /work3/s220243/Thesis/images/IBT 8189/RIS1_0_TL_20_preset/82.jpeg
# /work3/s220243/Thesis/images/IBT 41688/6w_top_medium_preset/104.jpeg
# /work3/s220243/Thesis/images/IBT 8189/RIS1_0_TL_20_preset/131.jpeg
# /work3/s220243/Thesis/images/IBT 36719/RIS1_0_TL_20_preset/70.jpeg
# /work3/s220243/Thesis/images/IBT 21902/6w_top_medium_preset/101.jpeg
# /work3/s220243/Thesis/images/IBT 36523/RIS1_0_TL_20_preset/48.jpeg
# /work3/s220243/Thesis/images/IBT 41023/6w_top_medium_preset/109.jpeg
# /work3/s220243/Thesis/images/IBT 9212/RIS1_0_TL_20_preset/88.jpeg
# /work3/s220243/Thesis/images/IBT 8121/RIS1_0_TL_20_preset/91.jpeg
# /work3/s220243/Thesis/images/IBT 41958/RIS1_0_TL_20_preset/54.jpeg
# /work3/s220243/Thesis/images/IBT 36716/RIS1_0_TL_20_preset/58.jpeg
# /work3/s220243/Thesis/images/IBT 36721/RIS1_0_TL_20_preset/123.jpeg
# /work3/s220243/Thesis/images/IBT 26504/RIS1_0_TL_20_preset/74.jpeg
# /work3/s220243/Thesis/images/IBT 41274/RIS1_0_TL_20_preset/87.jpeg
# /work3/s220243/Thesis/images/IBT 32786/RIS1_0_TL_20_preset/69.jpeg
# /work3/s220243/Thesis/images/IBT 13516/6w_top_medium_preset/90.jpeg
# /work3/s220243/Thesis/images/IBT 42145/6w_top_medium_preset/65.jpeg
# /work3/s220243/Thesis/images/IBT 36730/RIS1_0_TL_20_preset/100.jpeg
# /work3/s220243/Thesis/images/IBT 40303/6w_top_medium_preset/106.jpeg
# /work3/s220243/Thesis/images/IBT 32786/RIS1_0_TL_20_preset/75.jpeg
# /work3/s220243/Thesis/images/IBT 26878/RIS1_0_TL_20_preset/67.jpeg
# /work3/s220243/Thesis/images/IBT 31686/RIS1_0_TL_20_preset/136.jpeg
# /work3/s220243/Thesis/images/IBT 42760/RIS1_0_TL_20_preset/100.jpeg
# /work3/s220243/Thesis/images/IBT 36730/RIS1_0_TL_20_preset/76.jpeg
# /work3/s220243/Thesis/images/IBT 26950/RIS1_0_TL_20_preset/55.jpeg
# /work3/s220243/Thesis/images/IBT 23138/6w_top_medium_preset/93.jpeg
# /work3/s220243/Thesis/images/IBT 8189/RIS1_0_TL_20_preset/111.jpeg
# /work3/s220243/Thesis/images/IBT 42899/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 34291/6w_top_medium_preset/128.jpeg
# /work3/s220243/Thesis/images/IBT 9051/RIS1_0_TL_20_preset/76.jpeg
# /work3/s220243/Thesis/images/IBT 36710/RIS1_0_TL_20_preset/69.jpeg
# /work3/s220243/Thesis/images/IBT 7737/RIS1_0_TL_20_preset/85.jpeg
# /work3/s220243/Thesis/images/IBT 36710/RIS1_0_TL_20_preset/126.jpeg
# /work3/s220243/Thesis/images/IBT 41912/RIS1_0_TL_20_preset/97.jpeg
# /work3/s220243/Thesis/images/IBT 41269/RIS1_0_TL_20_preset/105.jpeg
# /work3/s220243/Thesis/images/IBT 42851/RIS1_0_TL_20_preset/91.jpeg
# /work3/s220243/Thesis/images/IBT 41891/RIS1_0_TL_20_preset/117.jpeg
# /work3/s220243/Thesis/images/IBT 42221/RIS1_0_TL_20_preset/52.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 27
#      24 print('copying...')
#      26 # Copy images to train directory
# ---> 27 copy_images(train_df, train_dst)
#      28 print('train images copy finished')
#      30 # Copy images to test directory
#
# Cell In[37], line 22, in copy_images(df, dst_folder)
#      20 target_dst.mkdir(exist_ok=True)
#      21 print(str(row['path']))
# ---> 22 shutil.copy(str(row['path']), str(target_dst))
#
# File ~/miniconda3/envs/fungi/lib/python3.12/shutil.py:435, in copy(src, dst, follow_symlinks)
#     433 if os.path.isdir(dst):
#     434     dst = os.path.join(dst, os.path.basename(src))
# --> 435 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436 copymode(src, dst, follow_symlinks=follow_symlinks)
#     437 return dst
#
# File ~/miniconda3/envs/fungi/lib/python3.12/shutil.py:273, in copyfile(src, dst, follow_symlinks)
#     271 elif _USE_CP_SENDFILE:
#     272     try:
# --> 273         _fastcopy_sendfile(fsrc, fdst)
#     274         return dst
#     275     except _GiveupOnFastCopy:
#
# File ~/miniconda3/envs/fungi/lib/python3.12/shutil.py:150, in _fastcopy_sendfile(fsrc, fdst)
#     148 while True:
#     149     try:
# --> 150         sent = os.sendfile(outfd, infd, offset, blocksize)
#     151     except OSError as err:
#     152         # ...in oder to have a more informative exception.
#     153         err.filename = fsrc.name
#
# KeyboardInterrupt:
